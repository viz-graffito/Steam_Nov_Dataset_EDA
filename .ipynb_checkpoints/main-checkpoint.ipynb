# %%
import pandas as pd

# %%
steam = pd.read_csv('steam_top_100.csv')
display(steam)
# Out:
#     Steam id                              Game  Current players  \
# 0        730  Counter-Strike: Global Offensive           736875
# 1        570                            Dota 2           580933
# 2    1063730                         New World           243815
# 3    1172470                      Apex Legends           121313
# 4        440                   Team Fortress 2           104477
# ..       ...                               ...              ...
# 95   1286830     STAR WARS™: The Old Republic™             7104
# 96   1644960                          NBA 2K22             7020
# 97    244210                     Assetto Corsa             6965
# 98    275850                      No Man's Sky             6963
# 99   1238810                    Battlefield™ V             6724
#
#     Peak players today Release date   Review summary  Total reviews  \
# 0               775266  21 Aug 2012    Very Positive      5993058.0
# 1               649690   9 Jul 2013    Very Positive      1599180.0
# 2               307146  28 Sep 2021  Mostly Positive       145931.0
# 3               245235   4 Nov 2020    Very Positive       338236.0
# 4               111884  10 Oct 2007    Very Positive       821568.0
# ..                 ...          ...              ...            ...
# 95                9345  21 Jul 2020    Very Positive        33098.0
# 96               13139   9 Sep 2021            Mixed         6266.0
# 97                8707  19 Dec 2014    Very Positive        42497.0
# 98               10122  12 Aug 2016  Mostly Positive       168792.0
# 99               33310  22 Oct 2020  Mostly Positive        68109.0
#
#                                                  Tags
# 0   FPS:Shooter:Multiplayer:Competitive:Action:Tea...
# 1   Free to Play:MOBA:Multiplayer:Strategy:eSports...
# 2   Massively Multiplayer:Open World:MMORPG:Advent...
# 3   Free to Play:Battle Royale:Multiplayer:Shooter...
# 4   Free to Play:Hero Shooter:Multiplayer:FPS:Shoo...
# ..                                                ...
# 95  Free to Play:MMORPG:Character Customization:Mu...
# 96  Sports:Basketball:Simulation:eSports:Realistic...
# 97  Racing:Automobile Sim:Simulation:Driving:Reali...
# 98  Open World:Open World Survival Craft:Space:Exp...
# 99  FPS:World War II:Shooter:Multiplayer:War:Singl...
#
# [100 rows x 8 columns]

# %%
#check data type of each variable
print(steam.shape)
steam.dtypes
# Out:
# (100, 8)
# Steam id                int64
# Game                   object
# Current players         int64
# Peak players today      int64
# Release date           object
# Review summary         object
# Total reviews         float64
# Tags                   object
# dtype: object

# %% [markdown]
# - review summary is qualitative ordinal variable therefore its better to catagorize it. Also apply encoding.
# - change release date to 'datetime' data type
# - One-Hot-Encoding to do the tags column

# %%
#check the unique value of Review Summary
print(steam['Review summary'].unique())
# Out:
# ['Very Positive' 'Mostly Positive' 'Mixed' 'Overwhelmingly Positive' nan]

# %%
#check the NaN values
print(steam.isnull().sum())
# Out:
# Steam id              0
# Game                  0
# Current players       0
# Peak players today    0
# Release date          1
# Review summary        1
# Total reviews         1
# Tags                  2
# dtype: int64

# %%
#getting rid of null values in Review summary
#replacing the null value to the most frequent value in Review summary variable.

#first categorize this variable
steam['Review summary'] = pd.Categorical(steam['Review summary'], ['Mixed','Very Positive', 'Mostly Positive', 'Overwhelmingly Positive'], ordered = True)

#make new variable for Categorical encoding
steam['Review summary encoded'] = steam['Review summary'].cat.codes

print(steam['Review summary encoded'].mode())
print(steam['Review summary encoded'].unique())
# Out:
# 0    1
# dtype: int8
# [ 1  2  0  3 -1]

# %% [markdown]
# - 'Very Positive' turn out to be the mode in this variable.

# %%
#lets replace nan value to 'Very positive'
steam = steam.fillna(value = {'Review summary': 'Very Positive'})
steam['Review summary encoded'] = steam['Review summary encoded'].replace('-1',1)
print(steam['Review summary'].unique())
print(steam['Review summary encoded'].unique())
# Out:
# ['Very Positive', 'Mostly Positive', 'Mixed', 'Overwhelmingly Positive']
# Categories (4, object): ['Mixed' < 'Very Positive' < 'Mostly Positive' < 'Overwhelmingly Positive']
# [ 1  2  0  3 -1]

# %%
steam.head()
# Out:
#    Steam id                              Game  Current players  \
# 0       730  Counter-Strike: Global Offensive           736875
# 1       570                            Dota 2           580933
# 2   1063730                         New World           243815
# 3   1172470                      Apex Legends           121313
# 4       440                   Team Fortress 2           104477
#
#    Peak players today Release date   Review summary  Total reviews  \
# 0              775266  21 Aug 2012    Very Positive      5993058.0
# 1              649690   9 Jul 2013    Very Positive      1599180.0
# 2              307146  28 Sep 2021  Mostly Positive       145931.0
# 3              245235   4 Nov 2020    Very Positive       338236.0
# 4              111884  10 Oct 2007    Very Positive       821568.0
#
#                                                 Tags  Review summary encoded
# 0  FPS:Shooter:Multiplayer:Competitive:Action:Tea...                       1
# 1  Free to Play:MOBA:Multiplayer:Strategy:eSports...                       1
# 2  Massively Multiplayer:Open World:MMORPG:Advent...                       2
# 3  Free to Play:Battle Royale:Multiplayer:Shooter...                       1
# 4  Free to Play:Hero Shooter:Multiplayer:FPS:Shoo...                       1

# %%
#getting rid of null values in total reviews.
#also change data type to int.

#Total review is a discrete quantitative variable so we can not put central tendency of this variable.
steam = steam.dropna(subset=['Total reviews'])
steam.isnull().sum()
steam['Total reviews'] = steam['Total reviews'].astype('int')
steam.dtypes

# total review datatype is now int
# Out:
# Steam id                     int64
# Game                        object
# Current players              int64
# Peak players today           int64
# Release date                object
# Review summary            category
# Total reviews                int32
# Tags                        object
# Review summary encoded        int8
# dtype: object

# %%
#Now lets move to the tags variable.
#One-Hot-Encoding for tags variable.

# steam['Tags'] = steam.Tags.replace(':',',')
temp = steam.Tags.str.split(':', expand= True)
# steam = pd.get_dummies(data = steam, columns = 'new')
# temp = temp.to_frame()
print(type(temp))
print(temp)
temp.columns = ['zero','one', 'tow','three','four','five','six','seven','eight','nine','ten','eleven','twelve','thirteen','fourteen','fifteen','sixteen','seventeen','eighteen','nineteen']
# temp = pd.get_dummies(data = temp, columns = 'zero')
# temp['sor'] = temp.apply(lambda row: sorted([row[0],row[1],row[2],row[3],row[4]]), axis=1)
display(temp)
# display(sor)
# display(temp.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                        0                          1                        2   \
# 0                     FPS                    Shooter              Multiplayer
# 1            Free to Play                       MOBA              Multiplayer
# 2   Massively Multiplayer                 Open World                   MMORPG
# 3            Free to Play              Battle Royale              Multiplayer
# 4            Free to Play               Hero Shooter              Multiplayer
# ..                    ...                        ...                      ...
# 95           Free to Play                     MMORPG  Character Customization
# 96                 Sports                 Basketball               Simulation
# 97                 Racing             Automobile Sim               Simulation
# 98             Open World  Open World Survival Craft                    Space
# 99                    FPS               World War II                  Shooter
#
#              3             4             5                      6   \
# 0   Competitive        Action    Team-Based                eSports
# 1      Strategy       eSports    Team-Based            Competitive
# 2     Adventure           RPG        Action                    PvP
# 3       Shooter  First-Person           PvP                    FPS
# 4           FPS       Shooter        Action            Class-Based
# ..          ...           ...           ...                    ...
# 95  Multiplayer    Open World           RPG  Massively Multiplayer
# 96      eSports     Realistic   Multiplayer                     3D
# 97      Driving     Realistic   Multiplayer                 Sports
# 98  Exploration        Sci-fi      Survival  Procedural Generation
# 99  Multiplayer           War  Singleplayer           First-Person
#
#               7             8             9                        10  \
# 0       Tactical  First-Person           PvP             Online Co-Op
# 1         Action  Online Co-Op           PvP                Difficult
# 2            PvE   Multiplayer       Fantasy  Character Customization
# 3   Hero Shooter        Action    Team-Based                 Survival
# 4     Team-Based         Funny  First-Person             Online Co-Op
# ..           ...           ...           ...                      ...
# 95    Story Rich        Sci-fi     Adventure           Choices Matter
# 96  Singleplayer    Team-Based    Management  Character Customization
# 97            VR      Moddable    Controller                  Physics
# 98     Adventure  First-Person       Sandbox             Singleplayer
# 99      Military           PvP    Open World                   Combat
#
#                          11            12                 13  \
# 0                     Co-op      Strategy           Military
# 1                     Co-op           RTS      Tower Defense
# 2                  Crafting  Third Person  Walking Simulator
# 3   Character Customization        Sci-fi           Tactical
# 4               Competitive      Cartoony            Trading
# ..                      ...           ...                ...
# 95                   Action         Space       Third Person
# 96               Controller  Deckbuilding            Trading
# 97             Singleplayer    Open World       First-Person
# 98              Atmospheric   Multiplayer           Crafting
# 99    Massively Multiplayer        Action         Historical
#
#                            14            15                       16  \
# 0                         War     Difficult                  Trading
# 1                     Fantasy           RPG  Character Customization
# 2   Open World Survival Craft       Sandbox                    Co-op
# 3                        Loot         Funny                Lore-Rich
# 4                       Co-op        Comedy                   Robots
# ..                        ...           ...                      ...
# 95                        PvP   Atmospheric               Action RPG
# 96             4 Player Local         Co-op              Local Co-Op
# 97                      Indie  Replay Value                   Action
# 98                  Space Sim         Indie                   Action
# 99                Destruction   Atmospheric            Battle Royale
#
#                  17                 18                       19
# 0         Realistic         Fast-Paced                 Moddable
# 1      Replay Value         Action RPG               Simulation
# 2           Violent         Souls-like           Sexual Content
# 3         Cyberpunk          Cinematic                  Science
# 4          Tactical            Cartoon                 Crafting
# ..              ...                ...                      ...
# 95  Party-Based RPG   Great Soundtrack                     CRPG
# 96         Gambling  Local Multiplayer             Online Co-Op
# 97        3D Vision            TrackIR  Artificial Intelligence
# 98       Simulation                FPS         Great Soundtrack
# 99          Violent     Sexual Content       Female Protagonist
#
# [99 rows x 20 columns]
#                      zero                        one                      tow  \
# 0                     FPS                    Shooter              Multiplayer
# 1            Free to Play                       MOBA              Multiplayer
# 2   Massively Multiplayer                 Open World                   MMORPG
# 3            Free to Play              Battle Royale              Multiplayer
# 4            Free to Play               Hero Shooter              Multiplayer
# ..                    ...                        ...                      ...
# 95           Free to Play                     MMORPG  Character Customization
# 96                 Sports                 Basketball               Simulation
# 97                 Racing             Automobile Sim               Simulation
# 98             Open World  Open World Survival Craft                    Space
# 99                    FPS               World War II                  Shooter
#
#           three          four          five                    six  \
# 0   Competitive        Action    Team-Based                eSports
# 1      Strategy       eSports    Team-Based            Competitive
# 2     Adventure           RPG        Action                    PvP
# 3       Shooter  First-Person           PvP                    FPS
# 4           FPS       Shooter        Action            Class-Based
# ..          ...           ...           ...                    ...
# 95  Multiplayer    Open World           RPG  Massively Multiplayer
# 96      eSports     Realistic   Multiplayer                     3D
# 97      Driving     Realistic   Multiplayer                 Sports
# 98  Exploration        Sci-fi      Survival  Procedural Generation
# 99  Multiplayer           War  Singleplayer           First-Person
#
#            seven         eight          nine                      ten  \
# 0       Tactical  First-Person           PvP             Online Co-Op
# 1         Action  Online Co-Op           PvP                Difficult
# 2            PvE   Multiplayer       Fantasy  Character Customization
# 3   Hero Shooter        Action    Team-Based                 Survival
# 4     Team-Based         Funny  First-Person             Online Co-Op
# ..           ...           ...           ...                      ...
# 95    Story Rich        Sci-fi     Adventure           Choices Matter
# 96  Singleplayer    Team-Based    Management  Character Customization
# 97            VR      Moddable    Controller                  Physics
# 98     Adventure  First-Person       Sandbox             Singleplayer
# 99      Military           PvP    Open World                   Combat
#
#                      eleven        twelve           thirteen  \
# 0                     Co-op      Strategy           Military
# 1                     Co-op           RTS      Tower Defense
# 2                  Crafting  Third Person  Walking Simulator
# 3   Character Customization        Sci-fi           Tactical
# 4               Competitive      Cartoony            Trading
# ..                      ...           ...                ...
# 95                   Action         Space       Third Person
# 96               Controller  Deckbuilding            Trading
# 97             Singleplayer    Open World       First-Person
# 98              Atmospheric   Multiplayer           Crafting
# 99    Massively Multiplayer        Action         Historical
#
#                      fourteen       fifteen                  sixteen  \
# 0                         War     Difficult                  Trading
# 1                     Fantasy           RPG  Character Customization
# 2   Open World Survival Craft       Sandbox                    Co-op
# 3                        Loot         Funny                Lore-Rich
# 4                       Co-op        Comedy                   Robots
# ..                        ...           ...                      ...
# 95                        PvP   Atmospheric               Action RPG
# 96             4 Player Local         Co-op              Local Co-Op
# 97                      Indie  Replay Value                   Action
# 98                  Space Sim         Indie                   Action
# 99                Destruction   Atmospheric            Battle Royale
#
#           seventeen           eighteen                 nineteen
# 0         Realistic         Fast-Paced                 Moddable
# 1      Replay Value         Action RPG               Simulation
# 2           Violent         Souls-like           Sexual Content
# 3         Cyberpunk          Cinematic                  Science
# 4          Tactical            Cartoon                 Crafting
# ..              ...                ...                      ...
# 95  Party-Based RPG   Great Soundtrack                     CRPG
# 96         Gambling  Local Multiplayer             Online Co-Op
# 97        3D Vision            TrackIR  Artificial Intelligence
# 98       Simulation                FPS         Great Soundtrack
# 99          Violent     Sexual Content       Female Protagonist
#
# [99 rows x 20 columns]
